# %% [markdown]
# <a href="https://colab.research.google.com/github/hagaramr2005/DSA-From-Scratch/blob/main/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hagaramr2005/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# #Task type: Classification.
#
# The goal is to classify whether a piece of content needs to be refreshed or not based on its performance metrics.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# #Target (proxy): trend_direction
#
# The model predicts whether the content trend is up, stable, or down using historical performance data.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# # Success metric: F1-score.
#
# F1-score is suitable because it balances precision and recall when predicting the correct trend class.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv("content_refresh_anonymized.csv")

df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
df[[
    "content_id",
    "content_type",
    "pageviews_90d",
    "ctr",
    "engagement_rate",
    "trend_direction"
]].head()
# Out:
#              content_id     content_type  pageviews_90d   ctr  \
# 0  content_304f48230142  keyword article             22  0.76
# 1  content_a1fb4e703a9e  keyword article             10  0.05
# 2  content_9aa793d4d895  keyword article             14  0.09
# 3  content_331d6c4de07b  keyword article             87  0.49
# 4  content_d99b7a2d90ca  keyword article            177  0.13
#
#    engagement_rate trend_direction
# 0             5.88            down
# 1             0.00            down
# 2             0.00            down
# 3             1.28          stable
# 4             0.00            down

# %% [markdown]
# One row represents one content item.
#
# Each row contains the performance metrics for a single piece of content over time.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule cannot capture all the factors that affect content performance.
#
# The trend depends on many features such as search volume, CTR, engagement rate, impressions, content age, keyword competition, and average position.
#
# Machine learning can learn the relationship between these variables and predict the trend more accurately than simple if-else rules.

# %% [markdown]
# #One row represents one content item.
#
# Each row contains the performance metrics for a single piece of content over time.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
